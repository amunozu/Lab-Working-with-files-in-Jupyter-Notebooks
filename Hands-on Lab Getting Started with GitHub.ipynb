# %% [markdown]
# # "Data Science Tools"

# %% [markdown]
# ## "In this notebook, Data Science Tools and Ecosystem are summarized"

# %% [markdown]
# __Objectives:__
#
# - List for popular languages for data science
# - Mathematical operations
# - Time format changes
# - Create data tables
# - Common used libraries

# %% [markdown]
# Some of the popular languages that Data Scientist use are:
# - 1.- Python
# - 2.- R
# - 3.- Java
# - 4.- C++

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include: Numpy, Pandas, Polar

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 114.6 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.3.0 sympy-1.14.0

# %% [markdown]
# ### Let's take a look to the following examples:

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
minutos = 600
horas = minutos / 60
print (horas)
# Out:
# 10.0

# %% [markdown]
# ## AUTHOR
# Alejandro Muñoz Urzúa
